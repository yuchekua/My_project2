# %% [markdown]
# # HW5-1

# %% [markdown]
# __a. What is a suitable proximity measure for this dataset? Explain your choice.__ <br><br>
# Cosine similarity measure is a suitable proximity measure for this dataset. <br>
# Since the dataset can transfer into binary attributes and ordinal attributes with only 3 levels, <br>
# we can put each observation into sequences<br>
# Then we can calculate the Cosine similarity for each sequence<br> <br>
#
# __b. When examining the full data set, you notice that many categorical values are missing and coded as “N/A”. Explain how the missing values affect the result of clustering. Explain how to handle this problem without estimating the values nor discarding the corresponding records.__ <br><br>
#
# 1. Delete the observations if sample is small
# 2. Replace missing values with the most frequent value
# 3. Develop a model to predict missing values
# 4. Replace all 0 values with N/A.
# 5. Impute missing values by the mean of the data but it may distort useful information
# 6. Using the SimpleImputer class is an additional option for us. It substitutes a predetermined placeholder for the N/A values.
#
# - The use of clustering techniques, which aim to group points based on some similarity criterion, might be complicated by missing values.

# %% [markdown]
# # HW5-2

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn as skl

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2)
df =  skl.datasets.load_diabetes()
xt = tsne.fit_transform(df.data)
# Out:
# /Users/chriz_yu/opt/anaconda3/envs/CSE801/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /Users/chriz_yu/opt/anaconda3/envs/CSE801/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
plt.scatter(xt[:,0],xt[:,1])
plt.show()

# %%
# KMEANS
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=6)
kmeans.fit(xt)

plt.scatter(xt[:,0],xt[:,1],c=kmeans.labels_)
plt.show()

# %%
# DBSCAN
from sklearn.cluster import DBSCAN
DBS = DBSCAN(eps=2, min_samples=6).fit(xt)	
y_cls = DBS.labels_

plt.scatter(xt[:,0],xt[:,1],c=y_cls)
plt.show()
